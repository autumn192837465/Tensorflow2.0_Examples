# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import gc

from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.impute import SimpleImputer
from tensorflow.keras import optimizers
from tensorflow.keras import layers,Model

# %%
# import data
trainData = pd.read_csv('train.csv',header = 0)
testData = pd.read_csv('test.csv',header = 0)

# %%
# Deal with missing values
def nan_padding(data, columns):
    for column in columns:
        imputer=SimpleImputer()
        data[column]=imputer.fit_transform(data[column].values.reshape(-1,1))
    return data

columns = ["Age", "SibSp", "Parch","Fare"]

trainData = nan_padding(trainData, columns)
testData = nan_padding(testData, columns)

trainData.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0    0.0         A/5 21171   7.2500   NaN        S
# 1    0.0          PC 17599  71.2833   C85        C
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3    0.0            113803  53.1000  C123        S
# 4    0.0            373450   8.0500   NaN        S

# %%
# Drop useless data
def DropColumn(data, columns):    
    return data.drop(columns,axis = 1)


columns = ['Name',"Ticket", "Cabin","Embarked"]
trainData = DropColumn(trainData,columns)
testData = DropColumn(testData,columns)

trainData.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0            1         0       3    male  22.0    1.0    0.0   7.2500
# 1            2         1       1  female  38.0    1.0    0.0  71.2833
# 2            3         1       3  female  26.0    0.0    0.0   7.9250
# 3            4         1       1  female  35.0    1.0    0.0  53.1000
# 4            5         0       3    male  35.0    0.0    0.0   8.0500

# %%
def DummyData(data, columns):
    for c in columns:
        data = pd.concat([data,pd.get_dummies(data[c],prefix = c)],axis = 1)
        data = data.drop(c,axis = 1)
    return data

columns = ['Pclass']
trainData = DummyData(trainData,columns)
testData = DummyData(testData,columns)

trainData.head()
# Out:
#    PassengerId  Survived     Sex   Age  SibSp  Parch     Fare  Pclass_1  \
# 0            1         0    male  22.0    1.0    0.0   7.2500         0
# 1            2         1  female  38.0    1.0    0.0  71.2833         1
# 2            3         1  female  26.0    0.0    0.0   7.9250         0
# 3            4         1  female  35.0    1.0    0.0  53.1000         1
# 4            5         0    male  35.0    0.0    0.0   8.0500         0
#
#    Pclass_2  Pclass_3
# 0         0         1
# 1         0         0
# 2         0         1
# 3         0         0
# 4         0         1

# %%
def ConvertSex(data):
    le = LabelEncoder()
    le.fit(['male','female'])
    data['Sex'] = le.transform(data['Sex'])
    return
ConvertSex(trainData)
ConvertSex(testData)

trainData.head()
# Out:
#    PassengerId  Survived  Sex   Age  SibSp  Parch     Fare  Pclass_1  \
# 0            1         0    1  22.0    1.0    0.0   7.2500         0
# 1            2         1    0  38.0    1.0    0.0  71.2833         1
# 2            3         1    0  26.0    0.0    0.0   7.9250         0
# 3            4         1    0  35.0    1.0    0.0  53.1000         1
# 4            5         0    1  35.0    0.0    0.0   8.0500         0
#
#    Pclass_2  Pclass_3
# 0         0         1
# 1         0         0
# 2         0         1
# 3         0         0
# 4         0         1

# %%
def NormalizeData(data,columns):
    scaler = MinMaxScaler()
    for c in columns:
        data[c] = scaler.fit_transform(data[c].values.reshape(-1,1))
    return data


columns = ['Age','Fare']
trainData = NormalizeData(trainData,columns)
testData = NormalizeData(testData,columns)

trainData.head()
# Out:
#    PassengerId  Survived  Sex       Age  SibSp  Parch      Fare  Pclass_1  \
# 0            1         0    1  0.271174    1.0    0.0  0.014151         0
# 1            2         1    0  0.472229    1.0    0.0  0.139136         1
# 2            3         1    0  0.321438    0.0    0.0  0.015469         0
# 3            4         1    0  0.434531    1.0    0.0  0.103644         1
# 4            5         0    1  0.434531    0.0    0.0  0.015713         0
#
#    Pclass_2  Pclass_3
# 0         0         1
# 1         0         0
# 2         0         1
# 3         0         0
# 4         0         1

# %%
# train data after processing
trainData.head()
# Out:
#    PassengerId  Survived  Sex       Age  SibSp  Parch      Fare  Pclass_1  \
# 0            1         0    1  0.271174    1.0    0.0  0.014151         0
# 1            2         1    0  0.472229    1.0    0.0  0.139136         1
# 2            3         1    0  0.321438    0.0    0.0  0.015469         0
# 3            4         1    0  0.434531    1.0    0.0  0.103644         1
# 4            5         0    1  0.434531    0.0    0.0  0.015713         0
#
#    Pclass_2  Pclass_3
# 0         0         1
# 1         0         0
# 2         0         1
# 3         0         0
# 4         0         1

# %%
# test data after processing
testData.head()
# Out:
#    PassengerId  Sex       Age  SibSp  Parch      Fare  Pclass_1  Pclass_2  \
# 0          892    1  0.452723    0.0    0.0  0.015282         0         0
# 1          893    0  0.617566    1.0    0.0  0.013663         0         0
# 2          894    1  0.815377    0.0    0.0  0.018909         0         1
# 3          895    1  0.353818    0.0    0.0  0.016908         0         0
# 4          896    0  0.287881    1.0    1.0  0.023984         0         0
#
#    Pclass_3
# 0         1
# 1         1
# 2         0
# 3         1
# 4         1

# %%
trainX = trainData.iloc[:,2:].to_numpy()
trainY = trainData.loc[:,'Survived'].to_numpy()
testX = testData.iloc[:,1:].to_numpy()
testY = pd.read_csv('gender_submission.csv',header = 0).iloc[:,1].to_numpy()

# %%
# Check point
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = "./checkpoint" , 
                                                 save_weights_only = True,
                                                 save_best_only = True,
                                                 peroid=5, 
                                                 verbose = 1)

# %%
def CreateModel():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(units = 1024, 
                              activation = tf.nn.relu, 
                              input_shape=(8,), 
                              kernel_initializer = tf.initializers.RandomUniform(),
                              kernel_regularizer = tf.keras.regularizers.l1(0.0001)
                             ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(units = 2048, 
                              activation = tf.nn.relu,                               
                              kernel_initializer = tf.initializers.RandomUniform(),
                              kernel_regularizer = tf.keras.regularizers.l1(0.0001)
                             ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(units = 2048, 
                              activation = tf.nn.relu,                               
                              kernel_initializer = tf.initializers.RandomUniform(),
                              kernel_regularizer = tf.keras.regularizers.l1(0.0001)
                             ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(units = 2048, 
                              activation = tf.nn.relu,                               
                              kernel_initializer = tf.initializers.RandomUniform(),
                              kernel_regularizer = tf.keras.regularizers.l1(0.0001)
                             ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(units = 1024, 
                              activation = tf.nn.relu,                               
                              kernel_initializer = tf.initializers.RandomUniform(),
                              kernel_regularizer = tf.keras.regularizers.l1(0.0001)
                             ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1,activation='sigmoid')
    ])
    return model

# %%
model = CreateModel()
model.compile(loss = 'binary_crossentropy',
             optimizer=tf.keras.optimizers.Adam(lr = 0.00001),
             metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              9216
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              2099200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 12,600,321
# Trainable params: 12,600,321
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x = trainX,
          y = trainY,
          epochs = 2000,
          verbose = 2,
          validation_data = (testX,testY),
          callbacks=[cp_callback],
         )
# Out:
# Train on 891 samples, validate on 418 samples
# Epoch 1/2000
#
# Epoch 00001: val_loss improved from inf to 31.85153, saving model to ./checkpoint
# 891/891 - 14s - loss: 32.0182 - accuracy: 0.5791 - val_loss: 31.8515 - val_accuracy: 0.6364
# Epoch 2/2000
#
# Epoch 00002: val_loss improved from 31.85153 to 31.54195, saving model to ./checkpoint
# 891/891 - 7s - loss: 31.7100 - accuracy: 0.6162 - val_loss: 31.5419 - val_accuracy: 0.6364
# Epoch 3/2000
#
# Epoch 00003: val_loss improved from 31.54195 to 31.23155, saving model to ./checkpoint
# 891/891 - 8s - loss: 31.4071 - accuracy: 0.6162 - val_loss: 31.2316 - val_accuracy: 0.6364
# Epoch 4/2000
#
# Epoch 00004: val_loss improved from 31.23155 to 30.91995, saving model to ./checkpoint
# 891/891 - 7s - loss: 31.1057 - accuracy: 0.6162 - val_loss: 30.9200 - val_accuracy: 0.6364
# Epoch 5/2000
#
# Epoch 00005: val_loss improved from 30.91995 to 30.61080, saving model to ./checkpoint
# 891/891 - 6s - loss: 30.8072 - accuracy: 0.6162 - val_loss: 30.6108 - val_accuracy: 0.6364
# Epoch 6/2000
#
# Epoch 00006: val_loss improved from 30.61080 to 30.30155, saving model to ./checkpoint
# 891/891 - 9s - loss: 30.5075 - accuracy: 0.6162 - val_loss: 30.3016 - val_accuracy: 0.6364
# Epoch 7/2000
#
# Epoch 00007: val_loss improved from 30.30155 to 29.99391, saving model to ./checkpoint
# 891/891 - 7s - loss: 30.2126 - accuracy: 0.6173 - val_loss: 29.9939 - val_accuracy: 0.6435
# Epoch 8/2000
#
# Epoch 00008: val_loss improved from 29.99391 to 29.68942, saving model to ./checkpoint
# 891/891 - 10s - loss: 29.9176 - accuracy: 0.6207 - val_loss: 29.6894 - val_accuracy: 0.7273
# Epoch 9/2000
#
# Epoch 00009: val_loss improved from 29.68942 to 29.38649, saving model to ./checkpoint
# 891/891 - 9s - loss: 29.6280 - accuracy: 0.6846 - val_loss: 29.3865 - val_accuracy: 0.7895
# Epoch 10/2000
#
# Epoch 00010: val_loss improved from 29.38649 to 29.08825, saving model to ./checkpoint
# 891/891 - 7s - loss: 29.3383 - accuracy: 0.7363 - val_loss: 29.0882 - val_accuracy: 0.8397
# Epoch 11/2000
#
# Epoch 00011: val_loss improved from 29.08825 to 28.79043, saving model to ./checkpoint
# 891/891 - 7s - loss: 29.0536 - accuracy: 0.7531 - val_loss: 28.7904 - val_accuracy: 0.8397
# Epoch 12/2000
#
# Epoch 00012: val_loss improved from 28.79043 to 28.50257, saving model to ./checkpoint
# 891/891 - 7s - loss: 28.7736 - accuracy: 0.7800 - val_loss: 28.5026 - val_accuracy: 0.8373
# Epoch 13/2000
#
# Epoch 00013: val_loss improved from 28.50257 to 28.21846, saving model to ./checkpoint
# 891/891 - 8s - loss: 28.5002 - accuracy: 0.7789 - val_loss: 28.2185 - val_accuracy: 0.8325
# Epoch 14/2000
#
# Epoch 00014: val_loss improved from 28.21846 to 27.93727, saving model to ./checkpoint
# 891/891 - 7s - loss: 28.2243 - accuracy: 0.7845 - val_loss: 27.9373 - val_accuracy: 0.8373
# Epoch 15/2000
#
# Epoch 00015: val_loss improved from 27.93727 to 27.65851, saving model to ./checkpoint
# 891/891 - 12s - loss: 27.9486 - accuracy: 0.7811 - val_loss: 27.6585 - val_accuracy: 0.8373
# Epoch 16/2000
#
# Epoch 00016: val_loss improved from 27.65851 to 27.38255, saving model to ./checkpoint
# 891/891 - 8s - loss: 27.6798 - accuracy: 0.7901 - val_loss: 27.3826 - val_accuracy: 0.8397
# Epoch 17/2000
#
# Epoch 00017: val_loss improved from 27.38255 to 27.11284, saving model to ./checkpoint
# 891/891 - 6s - loss: 27.4183 - accuracy: 0.7800 - val_loss: 27.1128 - val_accuracy: 0.9258
# Epoch 18/2000
#
# Epoch 00018: val_loss improved from 27.11284 to 26.84616, saving model to ./checkpoint
# 891/891 - 6s - loss: 27.1568 - accuracy: 0.8025 - val_loss: 26.8462 - val_accuracy: 0.9402
# Epoch 19/2000
#
# Epoch 00019: val_loss improved from 26.84616 to 26.58465, saving model to ./checkpoint
# 891/891 - 7s - loss: 26.8973 - accuracy: 0.7991 - val_loss: 26.5847 - val_accuracy: 0.9378
# Epoch 20/2000
#
# Epoch 00020: val_loss improved from 26.58465 to 26.32742, saving model to ./checkpoint
# 891/891 - 8s - loss: 26.6478 - accuracy: 0.7969 - val_loss: 26.3274 - val_accuracy: 0.9378
# Epoch 21/2000
#
# Epoch 00021: val_loss improved from 26.32742 to 26.07103, saving model to ./checkpoint
# 891/891 - 6s - loss: 26.3901 - accuracy: 0.8025 - val_loss: 26.0710 - val_accuracy: 0.9785
# Epoch 22/2000
#
# Epoch 00022: val_loss improved from 26.07103 to 25.82274, saving model to ./checkpoint
# 891/891 - 6s - loss: 26.1415 - accuracy: 0.8103 - val_loss: 25.8227 - val_accuracy: 0.9522
# Epoch 23/2000
#
# Epoch 00023: val_loss improved from 25.82274 to 25.57715, saving model to ./checkpoint
# 891/891 - 6s - loss: 25.8976 - accuracy: 0.7980 - val_loss: 25.5772 - val_accuracy: 0.9498
# Epoch 24/2000
#
# Epoch 00024: val_loss improved from 25.57715 to 25.33549, saving model to ./checkpoint
# 891/891 - 6s - loss: 25.6520 - accuracy: 0.8114 - val_loss: 25.3355 - val_accuracy: 0.9522
# Epoch 25/2000
#
# Epoch 00025: val_loss improved from 25.33549 to 25.09551, saving model to ./checkpoint
# 891/891 - 6s - loss: 25.4083 - accuracy: 0.8047 - val_loss: 25.0955 - val_accuracy: 0.9522
# Epoch 26/2000
#
# Epoch 00026: val_loss improved from 25.09551 to 24.86308, saving model to ./checkpoint
# 891/891 - 6s - loss: 25.1730 - accuracy: 0.7980 - val_loss: 24.8631 - val_accuracy: 0.9522
# Epoch 27/2000
#
# Epoch 00027: val_loss improved from 24.86308 to 24.62062, saving model to ./checkpoint
# 891/891 - 6s - loss: 24.9325 - accuracy: 0.8002 - val_loss: 24.6206 - val_accuracy: 0.9641
# Epoch 28/2000
#
# Epoch 00028: val_loss improved from 24.62062 to 24.39222, saving model to ./checkpoint
# 891/891 - 7s - loss: 24.7000 - accuracy: 0.8114 - val_loss: 24.3922 - val_accuracy: 0.9450
# Epoch 29/2000
#
# Epoch 00029: val_loss improved from 24.39222 to 24.15155, saving model to ./checkpoint
# 891/891 - 6s - loss: 24.4652 - accuracy: 0.8047 - val_loss: 24.1515 - val_accuracy: 0.9545
# Epoch 30/2000
#
# Epoch 00030: val_loss improved from 24.15155 to 23.92398, saving model to ./checkpoint
# 891/891 - 6s - loss: 24.2348 - accuracy: 0.8036 - val_loss: 23.9240 - val_accuracy: 0.9617
# Epoch 31/2000
#
# Epoch 00031: val_loss improved from 23.92398 to 23.69691, saving model to ./checkpoint
# 891/891 - 8s - loss: 24.0051 - accuracy: 0.8025 - val_loss: 23.6969 - val_accuracy: 0.9569
# Epoch 32/2000
#
# Epoch 00032: val_loss improved from 23.69691 to 23.46932, saving model to ./checkpoint
# 891/891 - 8s - loss: 23.7785 - accuracy: 0.8070 - val_loss: 23.4693 - val_accuracy: 0.9450
# Epoch 33/2000
#
# Epoch 00033: val_loss improved from 23.46932 to 23.24295, saving model to ./checkpoint
# 891/891 - 7s - loss: 23.5491 - accuracy: 0.8092 - val_loss: 23.2430 - val_accuracy: 0.9545
# Epoch 34/2000
#
# Epoch 00034: val_loss improved from 23.24295 to 23.02491, saving model to ./checkpoint
# 891/891 - 7s - loss: 23.3262 - accuracy: 0.8114 - val_loss: 23.0249 - val_accuracy: 0.9545
# Epoch 35/2000
#
# Epoch 00035: val_loss improved from 23.02491 to 22.80025, saving model to ./checkpoint
# 891/891 - 7s - loss: 23.0993 - accuracy: 0.8114 - val_loss: 22.8002 - val_accuracy: 0.9545
# Epoch 36/2000
#
# Epoch 00036: val_loss improved from 22.80025 to 22.58179, saving model to ./checkpoint
# 891/891 - 7s - loss: 22.8790 - accuracy: 0.8103 - val_loss: 22.5818 - val_accuracy: 0.9569
# Epoch 37/2000
#
# Epoch 00037: val_loss improved from 22.58179 to 22.36200, saving model to ./checkpoint
# 891/891 - 7s - loss: 22.6645 - accuracy: 0.8013 - val_loss: 22.3620 - val_accuracy: 0.9522
# Epoch 38/2000
#
# Epoch 00038: val_loss improved from 22.36200 to 22.14689, saving model to ./checkpoint
# 891/891 - 7s - loss: 22.4416 - accuracy: 0.8114 - val_loss: 22.1469 - val_accuracy: 0.9330
# Epoch 39/2000
#
# Epoch 00039: val_loss improved from 22.14689 to 21.92883, saving model to ./checkpoint
# 891/891 - 6s - loss: 22.2234 - accuracy: 0.8148 - val_loss: 21.9288 - val_accuracy: 0.9641
# Epoch 40/2000
#
# Epoch 00040: val_loss improved from 21.92883 to 21.72021, saving model to ./checkpoint
# 891/891 - 7s - loss: 22.0082 - accuracy: 0.8070 - val_loss: 21.7202 - val_accuracy: 0.9354
# Epoch 41/2000
#
# Epoch 00041: val_loss improved from 21.72021 to 21.50710, saving model to ./checkpoint
# 891/891 - 7s - loss: 21.8010 - accuracy: 0.8092 - val_loss: 21.5071 - val_accuracy: 0.9474
# Epoch 42/2000
#
# Epoch 00042: val_loss improved from 21.50710 to 21.29771, saving model to ./checkpoint
# 891/891 - 7s - loss: 21.5817 - accuracy: 0.8047 - val_loss: 21.2977 - val_accuracy: 0.9498
# Epoch 43/2000
#
# Epoch 00043: val_loss improved from 21.29771 to 21.08764, saving model to ./checkpoint
# 891/891 - 6s - loss: 21.3709 - accuracy: 0.8036 - val_loss: 21.0876 - val_accuracy: 0.9426
# Epoch 44/2000
#
# Epoch 00044: val_loss improved from 21.08764 to 20.87540, saving model to ./checkpoint
# 891/891 - 6s - loss: 21.1629 - accuracy: 0.8126 - val_loss: 20.8754 - val_accuracy: 0.9498
# Epoch 45/2000
#
# Epoch 00045: val_loss improved from 20.87540 to 20.67137, saving model to ./checkpoint
# 891/891 - 6s - loss: 20.9483 - accuracy: 0.8137 - val_loss: 20.6714 - val_accuracy: 0.9426
# Epoch 46/2000
#
# Epoch 00046: val_loss improved from 20.67137 to 20.46290, saving model to ./checkpoint
# 891/891 - 7s - loss: 20.7509 - accuracy: 0.8137 - val_loss: 20.4629 - val_accuracy: 0.9402
# Epoch 47/2000
#
# Epoch 00047: val_loss improved from 20.46290 to 20.25762, saving model to ./checkpoint
# 891/891 - 6s - loss: 20.5358 - accuracy: 0.8159 - val_loss: 20.2576 - val_accuracy: 0.9450
# Epoch 48/2000
#
# Epoch 00048: val_loss improved from 20.25762 to 20.05175, saving model to ./checkpoint
# 891/891 - 7s - loss: 20.3408 - accuracy: 0.8070 - val_loss: 20.0518 - val_accuracy: 0.9450
# Epoch 49/2000
#
# Epoch 00049: val_loss improved from 20.05175 to 19.85267, saving model to ./checkpoint
# 891/891 - 6s - loss: 20.1389 - accuracy: 0.8070 - val_loss: 19.8527 - val_accuracy: 0.9378
# Epoch 50/2000
#
# Epoch 00050: val_loss improved from 19.85267 to 19.64910, saving model to ./checkpoint
# 891/891 - 6s - loss: 19.9267 - accuracy: 0.8103 - val_loss: 19.6491 - val_accuracy: 0.9450
# Epoch 51/2000
#
# Epoch 00051: val_loss improved from 19.64910 to 19.45474, saving model to ./checkpoint
# 891/891 - 6s - loss: 19.7239 - accuracy: 0.8126 - val_loss: 19.4547 - val_accuracy: 0.9426
# Epoch 52/2000
#
# Epoch 00052: val_loss improved from 19.45474 to 19.25435, saving model to ./checkpoint
# 891/891 - 6s - loss: 19.5278 - accuracy: 0.8092 - val_loss: 19.2543 - val_accuracy: 0.9426
# Epoch 53/2000
#
# Epoch 00053: val_loss improved from 19.25435 to 19.05765, saving model to ./checkpoint
# 891/891 - 6s - loss: 19.3284 - accuracy: 0.8092 - val_loss: 19.0577 - val_accuracy: 0.9474
# Epoch 54/2000
#
# Epoch 00054: val_loss improved from 19.05765 to 18.86288, saving model to ./checkpoint
# 891/891 - 6s - loss: 19.1339 - accuracy: 0.8148 - val_loss: 18.8629 - val_accuracy: 0.9426
# Epoch 55/2000
#
# Epoch 00055: val_loss improved from 18.86288 to 18.66599, saving model to ./checkpoint
# 891/891 - 6s - loss: 18.9367 - accuracy: 0.8182 - val_loss: 18.6660 - val_accuracy: 0.9450
# Epoch 56/2000
#
# Epoch 00056: val_loss improved from 18.66599 to 18.47799, saving model to ./checkpoint
# 891/891 - 6s - loss: 18.7437 - accuracy: 0.8103 - val_loss: 18.4780 - val_accuracy: 0.9354
# Epoch 57/2000
#
# Epoch 00057: val_loss improved from 18.47799 to 18.28752, saving model to ./checkpoint
# 891/891 - 7s - loss: 18.5482 - accuracy: 0.8159 - val_loss: 18.2875 - val_accuracy: 0.9330
# Epoch 58/2000
#
# Epoch 00058: val_loss improved from 18.28752 to 18.09260, saving model to ./checkpoint
# 891/891 - 6s - loss: 18.3570 - accuracy: 0.8215 - val_loss: 18.0926 - val_accuracy: 0.9378
# Epoch 59/2000
#
# Epoch 00059: val_loss improved from 18.09260 to 17.89745, saving model to ./checkpoint
# 891/891 - 7s - loss: 18.1615 - accuracy: 0.8171 - val_loss: 17.8975 - val_accuracy: 0.9498
# Epoch 60/2000
#
# Epoch 00060: val_loss improved from 17.89745 to 17.71137, saving model to ./checkpoint
# 891/891 - 6s - loss: 17.9740 - accuracy: 0.8126 - val_loss: 17.7114 - val_accuracy: 0.9402
# Epoch 61/2000
#
# Epoch 00061: val_loss improved from 17.71137 to 17.52297, saving model to ./checkpoint
# 891/891 - 8s - loss: 17.7879 - accuracy: 0.8193 - val_loss: 17.5230 - val_accuracy: 0.9402
# Epoch 62/2000
#
# Epoch 00062: val_loss improved from 17.52297 to 17.33710, saving model to ./checkpoint
# 891/891 - 8s - loss: 17.6019 - accuracy: 0.8070 - val_loss: 17.3371 - val_accuracy: 0.9450
# Epoch 63/2000
#
# Epoch 00063: val_loss improved from 17.33710 to 17.15718, saving model to ./checkpoint
# 891/891 - 7s - loss: 17.4207 - accuracy: 0.8025 - val_loss: 17.1572 - val_accuracy: 0.9378
# Epoch 64/2000
#
# Epoch 00064: val_loss improved from 17.15718 to 16.97184, saving model to ./checkpoint
# 891/891 - 6s - loss: 17.2272 - accuracy: 0.8159 - val_loss: 16.9718 - val_accuracy: 0.9426
# Epoch 65/2000
#
# Epoch 00065: val_loss improved from 16.97184 to 16.78851, saving model to ./checkpoint
# 891/891 - 7s - loss: 17.0397 - accuracy: 0.8159 - val_loss: 16.7885 - val_accuracy: 0.9378
# Epoch 66/2000
#
# Epoch 00066: val_loss improved from 16.78851 to 16.60788, saving model to ./checkpoint
# 891/891 - 7s - loss: 16.8656 - accuracy: 0.8159 - val_loss: 16.6079 - val_accuracy: 0.9354
# Epoch 67/2000
#
# Epoch 00067: val_loss improved from 16.60788 to 16.42767, saving model to ./checkpoint
# 891/891 - 7s - loss: 16.6785 - accuracy: 0.8126 - val_loss: 16.4277 - val_accuracy: 0.9378
# Epoch 68/2000
#
# Epoch 00068: val_loss improved from 16.42767 to 16.24586, saving model to ./checkpoint
# 891/891 - 7s - loss: 16.5019 - accuracy: 0.8137 - val_loss: 16.2459 - val_accuracy: 0.9426
# Epoch 69/2000
#
# Epoch 00069: val_loss improved from 16.24586 to 16.06810, saving model to ./checkpoint
# 891/891 - 6s - loss: 16.3258 - accuracy: 0.8126 - val_loss: 16.0681 - val_accuracy: 0.9474
# Epoch 70/2000
#
# Epoch 00070: val_loss improved from 16.06810 to 15.89899, saving model to ./checkpoint
# 891/891 - 7s - loss: 16.1457 - accuracy: 0.8193 - val_loss: 15.8990 - val_accuracy: 0.9354
# Epoch 71/2000
#
# Epoch 00071: val_loss improved from 15.89899 to 15.72145, saving model to ./checkpoint
# 891/891 - 6s - loss: 15.9660 - accuracy: 0.8159 - val_loss: 15.7214 - val_accuracy: 0.9450
# Epoch 72/2000
#
# Epoch 00072: val_loss improved from 15.72145 to 15.54681, saving model to ./checkpoint
# 891/891 - 7s - loss: 15.7946 - accuracy: 0.8148 - val_loss: 15.5468 - val_accuracy: 0.9354
# Epoch 73/2000
#
# Epoch 00073: val_loss improved from 15.54681 to 15.37272, saving model to ./checkpoint
# 891/891 - 7s - loss: 15.6253 - accuracy: 0.8103 - val_loss: 15.3727 - val_accuracy: 0.9402
# Epoch 74/2000
#
# Epoch 00074: val_loss improved from 15.37272 to 15.20252, saving model to ./checkpoint
# 891/891 - 7s - loss: 15.4473 - accuracy: 0.8204 - val_loss: 15.2025 - val_accuracy: 0.9378
# Epoch 75/2000
#
# Epoch 00075: val_loss improved from 15.20252 to 15.03264, saving model to ./checkpoint
# 891/891 - 7s - loss: 15.2747 - accuracy: 0.8182 - val_loss: 15.0326 - val_accuracy: 0.9330
# Epoch 76/2000
#
# Epoch 00076: val_loss improved from 15.03264 to 14.86249, saving model to ./checkpoint
# 891/891 - 8s - loss: 15.1120 - accuracy: 0.8148 - val_loss: 14.8625 - val_accuracy: 0.9402
# Epoch 77/2000
#
# Epoch 00077: val_loss improved from 14.86249 to 14.69647, saving model to ./checkpoint
# 891/891 - 7s - loss: 14.9382 - accuracy: 0.8148 - val_loss: 14.6965 - val_accuracy: 0.9378
# Epoch 78/2000
#
# Epoch 00078: val_loss improved from 14.69647 to 14.52442, saving model to ./checkpoint
# 891/891 - 7s - loss: 14.7715 - accuracy: 0.8159 - val_loss: 14.5244 - val_accuracy: 0.9450
# Epoch 79/2000
#
# Epoch 00079: val_loss improved from 14.52442 to 14.36126, saving model to ./checkpoint
# 891/891 - 7s - loss: 14.5953 - accuracy: 0.8260 - val_loss: 14.3613 - val_accuracy: 0.9450
# Epoch 80/2000
#
# Epoch 00080: val_loss improved from 14.36126 to 14.19495, saving model to ./checkpoint
# 891/891 - 6s - loss: 14.4347 - accuracy: 0.8193 - val_loss: 14.1949 - val_accuracy: 0.9426
# Epoch 81/2000
#
# Epoch 00081: val_loss improved from 14.19495 to 14.03128, saving model to ./checkpoint
# 891/891 - 6s - loss: 14.2673 - accuracy: 0.8114 - val_loss: 14.0313 - val_accuracy: 0.9426
# Epoch 82/2000
#
# Epoch 00082: val_loss improved from 14.03128 to 13.86901, saving model to ./checkpoint
# 891/891 - 6s - loss: 14.1125 - accuracy: 0.8171 - val_loss: 13.8690 - val_accuracy: 0.9426
# Epoch 83/2000
#
# Epoch 00083: val_loss improved from 13.86901 to 13.71062, saving model to ./checkpoint
# 891/891 - 6s - loss: 13.9519 - accuracy: 0.8092 - val_loss: 13.7106 - val_accuracy: 0.9450
# Epoch 84/2000
#
# Epoch 00084: val_loss improved from 13.71062 to 13.54752, saving model to ./checkpoint
# 891/891 - 6s - loss: 13.7835 - accuracy: 0.8182 - val_loss: 13.5475 - val_accuracy: 0.9450
# Epoch 85/2000
#
# Epoch 00085: val_loss improved from 13.54752 to 13.39355, saving model to ./checkpoint
# 891/891 - 6s - loss: 13.6316 - accuracy: 0.8182 - val_loss: 13.3936 - val_accuracy: 0.9402
# Epoch 86/2000
#
# Epoch 00086: val_loss improved from 13.39355 to 13.23242, saving model to ./checkpoint
# 891/891 - 6s - loss: 13.4635 - accuracy: 0.8227 - val_loss: 13.2324 - val_accuracy: 0.9450
# Epoch 87/2000
#
# Epoch 00087: val_loss improved from 13.23242 to 13.07678, saving model to ./checkpoint
# 891/891 - 7s - loss: 13.3070 - accuracy: 0.8148 - val_loss: 13.0768 - val_accuracy: 0.9450
# Epoch 88/2000
#
# Epoch 00088: val_loss improved from 13.07678 to 12.92286, saving model to ./checkpoint
# 891/891 - 7s - loss: 13.1509 - accuracy: 0.8159 - val_loss: 12.9229 - val_accuracy: 0.9378
# Epoch 89/2000
#
# Epoch 00089: val_loss improved from 12.92286 to 12.76512, saving model to ./checkpoint
# 891/891 - 6s - loss: 13.0004 - accuracy: 0.8126 - val_loss: 12.7651 - val_accuracy: 0.9450
# Epoch 90/2000
#
# Epoch 00090: val_loss improved from 12.76512 to 12.61363, saving model to ./checkpoint
# 891/891 - 6s - loss: 12.8422 - accuracy: 0.8148 - val_loss: 12.6136 - val_accuracy: 0.9378
# Epoch 91/2000
#
# Epoch 00091: val_loss improved from 12.61363 to 12.46430, saving model to ./checkpoint
# 891/891 - 7s - loss: 12.6948 - accuracy: 0.8114 - val_loss: 12.4643 - val_accuracy: 0.9426
# Epoch 92/2000
#
# Epoch 00092: val_loss improved from 12.46430 to 12.31272, saving model to ./checkpoint
# 891/891 - 7s - loss: 12.5432 - accuracy: 0.8092 - val_loss: 12.3127 - val_accuracy: 0.9426
# Epoch 93/2000
#
# Epoch 00093: val_loss improved from 12.31272 to 12.15933, saving model to ./checkpoint
# 891/891 - 7s - loss: 12.3858 - accuracy: 0.8148 - val_loss: 12.1593 - val_accuracy: 0.9498
# Epoch 94/2000
#
# Epoch 00094: val_loss improved from 12.15933 to 12.01411, saving model to ./checkpoint
# 891/891 - 7s - loss: 12.2440 - accuracy: 0.8159 - val_loss: 12.0141 - val_accuracy: 0.9450
# Epoch 95/2000
#
# Epoch 00095: val_loss improved from 12.01411 to 11.86686, saving model to ./checkpoint
# 891/891 - 6s - loss: 12.0941 - accuracy: 0.8159 - val_loss: 11.8669 - val_accuracy: 0.9426
# Epoch 96/2000
#
# Epoch 00096: val_loss improved from 11.86686 to 11.72524, saving model to ./checkpoint
# 891/891 - 6s - loss: 11.9494 - accuracy: 0.8171 - val_loss: 11.7252 - val_accuracy: 0.9330
# Epoch 97/2000
#
# Epoch 00097: val_loss improved from 11.72524 to 11.57909, saving model to ./checkpoint
# 891/891 - 6s - loss: 11.8056 - accuracy: 0.8114 - val_loss: 11.5791 - val_accuracy: 0.9402
# Epoch 98/2000
#
# Epoch 00098: val_loss improved from 11.57909 to 11.43508, saving model to ./checkpoint
# 891/891 - 6s - loss: 11.6542 - accuracy: 0.8294 - val_loss: 11.4351 - val_accuracy: 0.9402
# Epoch 99/2000
#
# Epoch 00099: val_loss improved from 11.43508 to 11.29184, saving model to ./checkpoint
# 891/891 - 7s - loss: 11.5171 - accuracy: 0.8159 - val_loss: 11.2918 - val_accuracy: 0.9402
# Epoch 100/2000
#
# Epoch 00100: val_loss improved from 11.29184 to 11.15455, saving model to ./checkpoint
# 891/891 - 6s - loss: 11.3739 - accuracy: 0.8148 - val_loss: 11.1545 - val_accuracy: 0.9378
# Epoch 101/2000
#
# Epoch 00101: val_loss improved from 11.15455 to 11.00918, saving model to ./checkpoint
# 891/891 - 6s - loss: 11.2332 - accuracy: 0.8092 - val_loss: 11.0092 - val_accuracy: 0.9426
# Epoch 102/2000
#
# Epoch 00102: val_loss improved from 11.00918 to 10.86637, saving model to ./checkpoint
# 891/891 - 6s - loss: 11.0891 - accuracy: 0.8137 - val_loss: 10.8664 - val_accuracy: 0.9474
# Epoch 103/2000
#
# Epoch 00103: val_loss improved from 10.86637 to 10.73994, saving model to ./checkpoint
# 891/891 - 6s - loss: 10.9542 - accuracy: 0.8227 - val_loss: 10.7399 - val_accuracy: 0.9378
# Epoch 104/2000
#
# Epoch 00104: val_loss improved from 10.73994 to 10.59979, saving model to ./checkpoint
# 891/891 - 6s - loss: 10.8149 - accuracy: 0.8215 - val_loss: 10.5998 - val_accuracy: 0.9426
# Epoch 105/2000
#
# Epoch 00105: val_loss improved from 10.59979 to 10.46809, saving model to ./checkpoint
# 891/891 - 6s - loss: 10.6793 - accuracy: 0.8182 - val_loss: 10.4681 - val_accuracy: 0.9354
# Epoch 106/2000
#
# Epoch 00106: val_loss improved from 10.46809 to 10.33022, saving model to ./checkpoint
# 891/891 - 7s - loss: 10.5435 - accuracy: 0.8081 - val_loss: 10.3302 - val_accuracy: 0.9426
# Epoch 107/2000
#
# Epoch 00107: val_loss improved from 10.33022 to 10.19830, saving model to ./checkpoint
# 891/891 - 7s - loss: 10.4141 - accuracy: 0.8215 - val_loss: 10.1983 - val_accuracy: 0.9378
# Epoch 108/2000
#
# Epoch 00108: val_loss improved from 10.19830 to 10.06823, saving model to ./checkpoint
# 891/891 - 7s - loss: 10.2808 - accuracy: 0.8114 - val_loss: 10.0682 - val_accuracy: 0.9426
# Epoch 109/2000
#
# Epoch 00109: val_loss improved from 10.06823 to 9.93978, saving model to ./checkpoint
# 891/891 - 7s - loss: 10.1489 - accuracy: 0.8159 - val_loss: 9.9398 - val_accuracy: 0.9378
# Epoch 110/2000
#
# Epoch 00110: val_loss improved from 9.93978 to 9.80945, saving model to ./checkpoint
# 891/891 - 6s - loss: 10.0214 - accuracy: 0.8193 - val_loss: 9.8094 - val_accuracy: 0.9426
# Epoch 111/2000
#
# Epoch 00111: val_loss improved from 9.80945 to 9.68263, saving model to ./checkpoint
# 891/891 - 6s - loss: 9.8931 - accuracy: 0.8193 - val_loss: 9.6826 - val_accuracy: 0.9402
# Epoch 112/2000
#
# Epoch 00112: val_loss improved from 9.68263 to 9.55589, saving model to ./checkpoint
# 891/891 - 6s - loss: 9.7641 - accuracy: 0.8159 - val_loss: 9.5559 - val_accuracy: 0.9426
# Epoch 113/2000
#
# Epoch 00113: val_loss improved from 9.55589 to 9.43196, saving model to ./checkpoint
# 891/891 - 6s - loss: 9.6390 - accuracy: 0.8215 - val_loss: 9.4320 - val_accuracy: 0.9354
# Epoch 114/2000
#
# Epoch 00114: val_loss improved from 9.43196 to 9.30541, saving model to ./checkpoint
# 891/891 - 6s - loss: 9.5169 - accuracy: 0.8193 - val_loss: 9.3054 - val_accuracy: 0.9354
# Epoch 115/2000
#
# Epoch 00115: val_loss improved from 9.30541 to 9.18501, saving model to ./checkpoint
# 891/891 - 6s - loss: 9.3907 - accuracy: 0.8193 - val_loss: 9.1850 - val_accuracy: 0.9426
# Epoch 116/2000
#
# Epoch 00116: val_loss improved from 9.18501 to 9.06252, saving model to ./checkpoint
# 891/891 - 6s - loss: 9.2586 - accuracy: 0.8249 - val_loss: 9.0625 - val_accuracy: 0.9402
# Epoch 117/2000
#
# Epoch 00117: val_loss improved from 9.06252 to 8.93686, saving model to ./checkpoint
# 891/891 - 6s - loss: 9.1540 - accuracy: 0.8126 - val_loss: 8.9369 - val_accuracy: 0.9426
# Epoch 118/2000
#
# Epoch 00118: val_loss improved from 8.93686 to 8.82103, saving model to ./checkpoint
# 891/891 - 6s - loss: 9.0220 - accuracy: 0.8204 - val_loss: 8.8210 - val_accuracy: 0.9378
# Epoch 119/2000
#
# Epoch 00119: val_loss improved from 8.82103 to 8.70287, saving model to ./checkpoint
# 891/891 - 6s - loss: 8.9099 - accuracy: 0.8204 - val_loss: 8.7029 - val_accuracy: 0.9402
# Epoch 120/2000
#
# Epoch 00120: val_loss improved from 8.70287 to 8.58827, saving model to ./checkpoint
# 891/891 - 6s - loss: 8.7888 - accuracy: 0.8148 - val_loss: 8.5883 - val_accuracy: 0.9354
# Epoch 121/2000
#
# Epoch 00121: val_loss improved from 8.58827 to 8.46998, saving model to ./checkpoint
# 891/891 - 6s - loss: 8.6730 - accuracy: 0.8148 - val_loss: 8.4700 - val_accuracy: 0.9426
# Epoch 122/2000
#
# Epoch 00122: val_loss improved from 8.46998 to 8.35958, saving model to ./checkpoint
# 891/891 - 6s - loss: 8.5590 - accuracy: 0.8204 - val_loss: 8.3596 - val_accuracy: 0.9402
# Epoch 123/2000
#
# Epoch 00123: val_loss improved from 8.35958 to 8.24725, saving model to ./checkpoint
# 891/891 - 6s - loss: 8.4488 - accuracy: 0.8036 - val_loss: 8.2473 - val_accuracy: 0.9378
# Epoch 124/2000
#
# Epoch 00124: val_loss improved from 8.24725 to 8.13538, saving model to ./checkpoint
# 891/891 - 6s - loss: 8.3312 - accuracy: 0.8204 - val_loss: 8.1354 - val_accuracy: 0.9426
# Epoch 125/2000
#
# Epoch 00125: val_loss improved from 8.13538 to 8.01982, saving model to ./checkpoint
# 891/891 - 6s - loss: 8.2154 - accuracy: 0.8272 - val_loss: 8.0198 - val_accuracy: 0.9306
# Epoch 126/2000
#
# Epoch 00126: val_loss improved from 8.01982 to 7.91621, saving model to ./checkpoint
# 891/891 - 6s - loss: 8.1126 - accuracy: 0.8204 - val_loss: 7.9162 - val_accuracy: 0.9330
# Epoch 127/2000
#
# Epoch 00127: val_loss improved from 7.91621 to 7.80669, saving model to ./checkpoint
# 891/891 - 6s - loss: 7.9999 - accuracy: 0.8159 - val_loss: 7.8067 - val_accuracy: 0.9426
# Epoch 128/2000
#
# Epoch 00128: val_loss improved from 7.80669 to 7.70055, saving model to ./checkpoint
# 891/891 - 6s - loss: 7.8851 - accuracy: 0.8193 - val_loss: 7.7006 - val_accuracy: 0.9306
# Epoch 129/2000
#
# Epoch 00129: val_loss improved from 7.70055 to 7.59371, saving model to ./checkpoint
# 891/891 - 6s - loss: 7.7878 - accuracy: 0.8103 - val_loss: 7.5937 - val_accuracy: 0.9258
# Epoch 130/2000
#
# Epoch 00130: val_loss improved from 7.59371 to 7.48916, saving model to ./checkpoint
# 891/891 - 6s - loss: 7.6808 - accuracy: 0.8148 - val_loss: 7.4892 - val_accuracy: 0.9330
# Epoch 131/2000
#
# Epoch 00131: val_loss improved from 7.48916 to 7.38614, saving model to ./checkpoint
# 891/891 - 6s - loss: 7.5733 - accuracy: 0.8215 - val_loss: 7.3861 - val_accuracy: 0.9282
# Epoch 132/2000
#
# Epoch 00132: val_loss improved from 7.38614 to 7.27982, saving model to ./checkpoint
# 891/891 - 6s - loss: 7.4713 - accuracy: 0.8148 - val_loss: 7.2798 - val_accuracy: 0.9426
# Epoch 133/2000
#
# Epoch 00133: val_loss improved from 7.27982 to 7.18386, saving model to ./checkpoint
# 891/891 - 6s - loss: 7.3670 - accuracy: 0.8193 - val_loss: 7.1839 - val_accuracy: 0.9234
# Epoch 134/2000
#
# Epoch 00134: val_loss improved from 7.18386 to 7.07963, saving model to ./checkpoint
# 891/891 - 6s - loss: 7.2760 - accuracy: 0.8114 - val_loss: 7.0796 - val_accuracy: 0.9306
# Epoch 135/2000
#
# Epoch 00135: val_loss improved from 7.07963 to 6.98043, saving model to ./checkpoint
# 891/891 - 6s - loss: 7.1708 - accuracy: 0.8204 - val_loss: 6.9804 - val_accuracy: 0.9450
# Epoch 136/2000
#
# Epoch 00136: val_loss improved from 6.98043 to 6.88693, saving model to ./checkpoint
# 891/891 - 6s - loss: 7.0749 - accuracy: 0.8171 - val_loss: 6.8869 - val_accuracy: 0.9450
# Epoch 137/2000
#
# Epoch 00137: val_loss improved from 6.88693 to 6.79100, saving model to ./checkpoint
# 891/891 - 6s - loss: 6.9788 - accuracy: 0.8193 - val_loss: 6.7910 - val_accuracy: 0.9426
# Epoch 138/2000
#
# Epoch 00138: val_loss improved from 6.79100 to 6.69364, saving model to ./checkpoint
# 891/891 - 6s - loss: 6.8887 - accuracy: 0.8182 - val_loss: 6.6936 - val_accuracy: 0.9426
# Epoch 139/2000
#
# Epoch 00139: val_loss improved from 6.69364 to 6.60338, saving model to ./checkpoint
# 891/891 - 7s - loss: 6.7867 - accuracy: 0.8114 - val_loss: 6.6034 - val_accuracy: 0.9306
# Epoch 140/2000
#
# Epoch 00140: val_loss improved from 6.60338 to 6.51105, saving model to ./checkpoint
# 891/891 - 7s - loss: 6.6918 - accuracy: 0.8215 - val_loss: 6.5110 - val_accuracy: 0.9378
# Epoch 141/2000
#
# Epoch 00141: val_loss improved from 6.51105 to 6.42328, saving model to ./checkpoint
# 891/891 - 8s - loss: 6.6003 - accuracy: 0.8182 - val_loss: 6.4233 - val_accuracy: 0.9306
# Epoch 142/2000
#
# Epoch 00142: val_loss improved from 6.42328 to 6.33186, saving model to ./checkpoint
# 891/891 - 6s - loss: 6.5081 - accuracy: 0.8294 - val_loss: 6.3319 - val_accuracy: 0.9330
# Epoch 143/2000
#
# Epoch 00143: val_loss improved from 6.33186 to 6.24166, saving model to ./checkpoint
# 891/891 - 6s - loss: 6.4250 - accuracy: 0.8092 - val_loss: 6.2417 - val_accuracy: 0.9378
# Epoch 144/2000
#
# Epoch 00144: val_loss improved from 6.24166 to 6.15325, saving model to ./checkpoint
# 891/891 - 6s - loss: 6.3387 - accuracy: 0.8171 - val_loss: 6.1533 - val_accuracy: 0.9402
# Epoch 145/2000
#
# Epoch 00145: val_loss improved from 6.15325 to 6.06726, saving model to ./checkpoint
# 891/891 - 6s - loss: 6.2454 - accuracy: 0.8249 - val_loss: 6.0673 - val_accuracy: 0.9354
# Epoch 146/2000
#
# Epoch 00146: val_loss improved from 6.06726 to 5.98722, saving model to ./checkpoint
# 891/891 - 6s - loss: 6.1633 - accuracy: 0.8126 - val_loss: 5.9872 - val_accuracy: 0.9282
# Epoch 147/2000
#
# Epoch 00147: val_loss improved from 5.98722 to 5.90088, saving model to ./checkpoint
# 891/891 - 6s - loss: 6.0813 - accuracy: 0.8193 - val_loss: 5.9009 - val_accuracy: 0.9426
# Epoch 148/2000
#
# Epoch 00148: val_loss improved from 5.90088 to 5.81892, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.9942 - accuracy: 0.8227 - val_loss: 5.8189 - val_accuracy: 0.9378
# Epoch 149/2000
#
# Epoch 00149: val_loss improved from 5.81892 to 5.73941, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.9165 - accuracy: 0.8171 - val_loss: 5.7394 - val_accuracy: 0.9306
# Epoch 150/2000
#
# Epoch 00150: val_loss improved from 5.73941 to 5.65947, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.8319 - accuracy: 0.8215 - val_loss: 5.6595 - val_accuracy: 0.9378
# Epoch 151/2000
#
# Epoch 00151: val_loss improved from 5.65947 to 5.58075, saving model to ./checkpoint
# 891/891 - 8s - loss: 5.7547 - accuracy: 0.8238 - val_loss: 5.5808 - val_accuracy: 0.9378
# Epoch 152/2000
#
# Epoch 00152: val_loss improved from 5.58075 to 5.50352, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.6789 - accuracy: 0.8249 - val_loss: 5.5035 - val_accuracy: 0.9354
# Epoch 153/2000
#
# Epoch 00153: val_loss improved from 5.50352 to 5.42972, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.5988 - accuracy: 0.8159 - val_loss: 5.4297 - val_accuracy: 0.9450
# Epoch 154/2000
#
# Epoch 00154: val_loss improved from 5.42972 to 5.35639, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.5283 - accuracy: 0.8283 - val_loss: 5.3564 - val_accuracy: 0.9378
# Epoch 155/2000
#
# Epoch 00155: val_loss improved from 5.35639 to 5.28345, saving model to ./checkpoint
# 891/891 - 7s - loss: 5.4585 - accuracy: 0.8171 - val_loss: 5.2835 - val_accuracy: 0.9306
# Epoch 156/2000
#
# Epoch 00156: val_loss improved from 5.28345 to 5.21017, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.3795 - accuracy: 0.8215 - val_loss: 5.2102 - val_accuracy: 0.9354
# Epoch 157/2000
#
# Epoch 00157: val_loss improved from 5.21017 to 5.14257, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.3132 - accuracy: 0.8126 - val_loss: 5.1426 - val_accuracy: 0.9330
# Epoch 158/2000
#
# Epoch 00158: val_loss improved from 5.14257 to 5.07535, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.2403 - accuracy: 0.8159 - val_loss: 5.0754 - val_accuracy: 0.9282
# Epoch 159/2000
#
# Epoch 00159: val_loss improved from 5.07535 to 5.00404, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.1700 - accuracy: 0.8215 - val_loss: 5.0040 - val_accuracy: 0.9378
# Epoch 160/2000
#
# Epoch 00160: val_loss improved from 5.00404 to 4.93781, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.1084 - accuracy: 0.8182 - val_loss: 4.9378 - val_accuracy: 0.9378
# Epoch 161/2000
#
# Epoch 00161: val_loss improved from 4.93781 to 4.87152, saving model to ./checkpoint
# 891/891 - 6s - loss: 5.0365 - accuracy: 0.8114 - val_loss: 4.8715 - val_accuracy: 0.9354
# Epoch 162/2000
#
# Epoch 00162: val_loss improved from 4.87152 to 4.80860, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.9802 - accuracy: 0.8092 - val_loss: 4.8086 - val_accuracy: 0.9378
# Epoch 163/2000
#
# Epoch 00163: val_loss improved from 4.80860 to 4.74745, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.9073 - accuracy: 0.8215 - val_loss: 4.7474 - val_accuracy: 0.9378
# Epoch 164/2000
#
# Epoch 00164: val_loss improved from 4.74745 to 4.68798, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.8477 - accuracy: 0.8260 - val_loss: 4.6880 - val_accuracy: 0.9330
# Epoch 165/2000
#
# Epoch 00165: val_loss improved from 4.68798 to 4.62870, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.7947 - accuracy: 0.8159 - val_loss: 4.6287 - val_accuracy: 0.9330
# Epoch 166/2000
#
# Epoch 00166: val_loss improved from 4.62870 to 4.56707, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.7292 - accuracy: 0.8193 - val_loss: 4.5671 - val_accuracy: 0.9426
# Epoch 167/2000
#
# Epoch 00167: val_loss improved from 4.56707 to 4.51190, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.6752 - accuracy: 0.8171 - val_loss: 4.5119 - val_accuracy: 0.9354
# Epoch 168/2000
#
# Epoch 00168: val_loss improved from 4.51190 to 4.45459, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.6119 - accuracy: 0.8238 - val_loss: 4.4546 - val_accuracy: 0.9282
# Epoch 169/2000
#
# Epoch 00169: val_loss improved from 4.45459 to 4.39688, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.5613 - accuracy: 0.8171 - val_loss: 4.3969 - val_accuracy: 0.9306
# Epoch 170/2000
#
# Epoch 00170: val_loss improved from 4.39688 to 4.34532, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.5133 - accuracy: 0.8171 - val_loss: 4.3453 - val_accuracy: 0.9306
# Epoch 171/2000
#
# Epoch 00171: val_loss improved from 4.34532 to 4.29460, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.4506 - accuracy: 0.8305 - val_loss: 4.2946 - val_accuracy: 0.9354
# Epoch 172/2000
#
# Epoch 00172: val_loss improved from 4.29460 to 4.24394, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.4011 - accuracy: 0.8148 - val_loss: 4.2439 - val_accuracy: 0.9354
# Epoch 173/2000
#
# Epoch 00173: val_loss improved from 4.24394 to 4.19554, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.3505 - accuracy: 0.8193 - val_loss: 4.1955 - val_accuracy: 0.9378
# Epoch 174/2000
#
# Epoch 00174: val_loss improved from 4.19554 to 4.14838, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.3026 - accuracy: 0.8159 - val_loss: 4.1484 - val_accuracy: 0.9354
# Epoch 175/2000
#
# Epoch 00175: val_loss improved from 4.14838 to 4.10463, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.2501 - accuracy: 0.8227 - val_loss: 4.1046 - val_accuracy: 0.9258
# Epoch 176/2000
#
# Epoch 00176: val_loss improved from 4.10463 to 4.05580, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.2072 - accuracy: 0.8238 - val_loss: 4.0558 - val_accuracy: 0.9282
# Epoch 177/2000
#
# Epoch 00177: val_loss improved from 4.05580 to 4.01141, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.1690 - accuracy: 0.8193 - val_loss: 4.0114 - val_accuracy: 0.9234
# Epoch 178/2000
#
# Epoch 00178: val_loss improved from 4.01141 to 3.96978, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.1175 - accuracy: 0.8249 - val_loss: 3.9698 - val_accuracy: 0.9330
# Epoch 179/2000
#
# Epoch 00179: val_loss improved from 3.96978 to 3.92812, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.0819 - accuracy: 0.8260 - val_loss: 3.9281 - val_accuracy: 0.9378
# Epoch 180/2000
#
# Epoch 00180: val_loss improved from 3.92812 to 3.88643, saving model to ./checkpoint
# 891/891 - 6s - loss: 4.0326 - accuracy: 0.8260 - val_loss: 3.8864 - val_accuracy: 0.9402
# Epoch 181/2000
#
# Epoch 00181: val_loss improved from 3.88643 to 3.84885, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.9932 - accuracy: 0.8227 - val_loss: 3.8489 - val_accuracy: 0.9354
# Epoch 182/2000
#
# Epoch 00182: val_loss improved from 3.84885 to 3.81277, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.9622 - accuracy: 0.8193 - val_loss: 3.8128 - val_accuracy: 0.9258
# Epoch 183/2000
#
# Epoch 00183: val_loss improved from 3.81277 to 3.77305, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.9178 - accuracy: 0.8260 - val_loss: 3.7730 - val_accuracy: 0.9306
# Epoch 184/2000
#
# Epoch 00184: val_loss improved from 3.77305 to 3.73458, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.8820 - accuracy: 0.8159 - val_loss: 3.7346 - val_accuracy: 0.9354
# Epoch 185/2000
#
# Epoch 00185: val_loss improved from 3.73458 to 3.69515, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.8494 - accuracy: 0.8193 - val_loss: 3.6952 - val_accuracy: 0.9378
# Epoch 186/2000
#
# Epoch 00186: val_loss improved from 3.69515 to 3.66301, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.8094 - accuracy: 0.8227 - val_loss: 3.6630 - val_accuracy: 0.9378
# Epoch 187/2000
#
# Epoch 00187: val_loss improved from 3.66301 to 3.63189, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.7795 - accuracy: 0.8171 - val_loss: 3.6319 - val_accuracy: 0.9306
# Epoch 188/2000
#
# Epoch 00188: val_loss improved from 3.63189 to 3.59607, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.7408 - accuracy: 0.8215 - val_loss: 3.5961 - val_accuracy: 0.9378
# Epoch 189/2000
#
# Epoch 00189: val_loss improved from 3.59607 to 3.56835, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.7126 - accuracy: 0.8260 - val_loss: 3.5683 - val_accuracy: 0.9211
# Epoch 190/2000
#
# Epoch 00190: val_loss improved from 3.56835 to 3.53297, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.6800 - accuracy: 0.8227 - val_loss: 3.5330 - val_accuracy: 0.9258
# Epoch 191/2000
#
# Epoch 00191: val_loss improved from 3.53297 to 3.49766, saving model to ./checkpoint
# 891/891 - 7s - loss: 3.6420 - accuracy: 0.8272 - val_loss: 3.4977 - val_accuracy: 0.9330
# Epoch 192/2000
#
# Epoch 00192: val_loss improved from 3.49766 to 3.46792, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.6140 - accuracy: 0.8148 - val_loss: 3.4679 - val_accuracy: 0.9354
# Epoch 193/2000
#
# Epoch 00193: val_loss improved from 3.46792 to 3.43804, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.5850 - accuracy: 0.8092 - val_loss: 3.4380 - val_accuracy: 0.9306
# Epoch 194/2000
#
# Epoch 00194: val_loss improved from 3.43804 to 3.40788, saving model to ./checkpoint
# 891/891 - 8s - loss: 3.5478 - accuracy: 0.8159 - val_loss: 3.4079 - val_accuracy: 0.9282
# Epoch 195/2000
#
# Epoch 00195: val_loss improved from 3.40788 to 3.37660, saving model to ./checkpoint
# 891/891 - 8s - loss: 3.5204 - accuracy: 0.8092 - val_loss: 3.3766 - val_accuracy: 0.9354
# Epoch 196/2000
#
# Epoch 00196: val_loss improved from 3.37660 to 3.34701, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.4917 - accuracy: 0.8227 - val_loss: 3.3470 - val_accuracy: 0.9330
# Epoch 197/2000
#
# Epoch 00197: val_loss improved from 3.34701 to 3.31942, saving model to ./checkpoint
# 891/891 - 7s - loss: 3.4596 - accuracy: 0.8272 - val_loss: 3.3194 - val_accuracy: 0.9354
# Epoch 198/2000
#
# Epoch 00198: val_loss improved from 3.31942 to 3.29093, saving model to ./checkpoint
# 891/891 - 8s - loss: 3.4319 - accuracy: 0.8249 - val_loss: 3.2909 - val_accuracy: 0.9330
# Epoch 199/2000
#
# Epoch 00199: val_loss improved from 3.29093 to 3.26029, saving model to ./checkpoint
# 891/891 - 8s - loss: 3.4078 - accuracy: 0.8238 - val_loss: 3.2603 - val_accuracy: 0.9282
# Epoch 200/2000
#
# Epoch 00200: val_loss improved from 3.26029 to 3.23333, saving model to ./checkpoint
# 891/891 - 8s - loss: 3.3732 - accuracy: 0.8193 - val_loss: 3.2333 - val_accuracy: 0.9354
# Epoch 201/2000
#
# Epoch 00201: val_loss improved from 3.23333 to 3.20486, saving model to ./checkpoint
# 891/891 - 7s - loss: 3.3513 - accuracy: 0.8204 - val_loss: 3.2049 - val_accuracy: 0.9378
# Epoch 202/2000
#
# Epoch 00202: val_loss improved from 3.20486 to 3.17991, saving model to ./checkpoint
# 891/891 - 7s - loss: 3.3203 - accuracy: 0.8148 - val_loss: 3.1799 - val_accuracy: 0.9234
# Epoch 203/2000
#
# Epoch 00203: val_loss improved from 3.17991 to 3.15049, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.2962 - accuracy: 0.8283 - val_loss: 3.1505 - val_accuracy: 0.9330
# Epoch 204/2000
#
# Epoch 00204: val_loss improved from 3.15049 to 3.12719, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.2638 - accuracy: 0.8204 - val_loss: 3.1272 - val_accuracy: 0.9330
# Epoch 205/2000
#
# Epoch 00205: val_loss improved from 3.12719 to 3.10073, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.2490 - accuracy: 0.8193 - val_loss: 3.1007 - val_accuracy: 0.9330
# Epoch 206/2000
#
# Epoch 00206: val_loss improved from 3.10073 to 3.07849, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.2147 - accuracy: 0.8215 - val_loss: 3.0785 - val_accuracy: 0.9282
# Epoch 207/2000
#
# Epoch 00207: val_loss improved from 3.07849 to 3.05216, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.1883 - accuracy: 0.8260 - val_loss: 3.0522 - val_accuracy: 0.9330
# Epoch 208/2000
#
# Epoch 00208: val_loss improved from 3.05216 to 3.02511, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.1637 - accuracy: 0.8171 - val_loss: 3.0251 - val_accuracy: 0.9354
# Epoch 209/2000
#
# Epoch 00209: val_loss improved from 3.02511 to 3.00170, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.1450 - accuracy: 0.8215 - val_loss: 3.0017 - val_accuracy: 0.9258
# Epoch 210/2000
#
# Epoch 00210: val_loss improved from 3.00170 to 2.97926, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.1165 - accuracy: 0.8227 - val_loss: 2.9793 - val_accuracy: 0.9330
# Epoch 211/2000
#
# Epoch 00211: val_loss improved from 2.97926 to 2.95520, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.0922 - accuracy: 0.8182 - val_loss: 2.9552 - val_accuracy: 0.9354
# Epoch 212/2000
#
# Epoch 00212: val_loss improved from 2.95520 to 2.92996, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.0674 - accuracy: 0.8193 - val_loss: 2.9300 - val_accuracy: 0.9354
# Epoch 213/2000
#
# Epoch 00213: val_loss improved from 2.92996 to 2.90917, saving model to ./checkpoint
# 891/891 - 7s - loss: 3.0435 - accuracy: 0.8249 - val_loss: 2.9092 - val_accuracy: 0.9306
# Epoch 214/2000
#
# Epoch 00214: val_loss improved from 2.90917 to 2.88679, saving model to ./checkpoint
# 891/891 - 7s - loss: 3.0247 - accuracy: 0.8272 - val_loss: 2.8868 - val_accuracy: 0.9282
# Epoch 215/2000
#
# Epoch 00215: val_loss improved from 2.88679 to 2.86347, saving model to ./checkpoint
# 891/891 - 6s - loss: 3.0017 - accuracy: 0.8272 - val_loss: 2.8635 - val_accuracy: 0.9354
# Epoch 216/2000
#
# Epoch 00216: val_loss improved from 2.86347 to 2.84274, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.9769 - accuracy: 0.8182 - val_loss: 2.8427 - val_accuracy: 0.9330
# Epoch 217/2000
#
# Epoch 00217: val_loss improved from 2.84274 to 2.82065, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.9658 - accuracy: 0.8182 - val_loss: 2.8207 - val_accuracy: 0.9330
# Epoch 218/2000
#
# Epoch 00218: val_loss improved from 2.82065 to 2.79871, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.9367 - accuracy: 0.8238 - val_loss: 2.7987 - val_accuracy: 0.9258
# Epoch 219/2000
#
# Epoch 00219: val_loss improved from 2.79871 to 2.77907, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.9153 - accuracy: 0.8171 - val_loss: 2.7791 - val_accuracy: 0.9378
# Epoch 220/2000
#
# Epoch 00220: val_loss improved from 2.77907 to 2.75773, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.8944 - accuracy: 0.8215 - val_loss: 2.7577 - val_accuracy: 0.9330
# Epoch 221/2000
#
# Epoch 00221: val_loss improved from 2.75773 to 2.73405, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.8745 - accuracy: 0.8272 - val_loss: 2.7340 - val_accuracy: 0.9378
# Epoch 222/2000
#
# Epoch 00222: val_loss improved from 2.73405 to 2.71532, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.8510 - accuracy: 0.8238 - val_loss: 2.7153 - val_accuracy: 0.9330
# Epoch 223/2000
#
# Epoch 00223: val_loss improved from 2.71532 to 2.69642, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.8358 - accuracy: 0.8171 - val_loss: 2.6964 - val_accuracy: 0.9330
# Epoch 224/2000
#
# Epoch 00224: val_loss improved from 2.69642 to 2.67729, saving model to ./checkpoint
# 891/891 - 7s - loss: 2.8139 - accuracy: 0.8171 - val_loss: 2.6773 - val_accuracy: 0.9354
# Epoch 225/2000
#
# Epoch 00225: val_loss improved from 2.67729 to 2.65895, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.7919 - accuracy: 0.8227 - val_loss: 2.6589 - val_accuracy: 0.9330
# Epoch 226/2000
#
# Epoch 00226: val_loss improved from 2.65895 to 2.63641, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.7738 - accuracy: 0.8159 - val_loss: 2.6364 - val_accuracy: 0.9258
# Epoch 227/2000
#
# Epoch 00227: val_loss improved from 2.63641 to 2.61946, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.7518 - accuracy: 0.8148 - val_loss: 2.6195 - val_accuracy: 0.9330
# Epoch 228/2000
#
# Epoch 00228: val_loss improved from 2.61946 to 2.59843, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.7343 - accuracy: 0.8305 - val_loss: 2.5984 - val_accuracy: 0.9234
# Epoch 229/2000
#
# Epoch 00229: val_loss improved from 2.59843 to 2.57886, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.7139 - accuracy: 0.8272 - val_loss: 2.5789 - val_accuracy: 0.9330
# Epoch 230/2000
#
# Epoch 00230: val_loss improved from 2.57886 to 2.55997, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.6979 - accuracy: 0.8227 - val_loss: 2.5600 - val_accuracy: 0.9378
# Epoch 231/2000
#
# Epoch 00231: val_loss improved from 2.55997 to 2.54221, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.6764 - accuracy: 0.8249 - val_loss: 2.5422 - val_accuracy: 0.9354
# Epoch 232/2000
#
# Epoch 00232: val_loss improved from 2.54221 to 2.52528, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.6593 - accuracy: 0.8260 - val_loss: 2.5253 - val_accuracy: 0.9330
# Epoch 233/2000
#
# Epoch 00233: val_loss improved from 2.52528 to 2.50713, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.6401 - accuracy: 0.8227 - val_loss: 2.5071 - val_accuracy: 0.9354
# Epoch 234/2000
#
# Epoch 00234: val_loss improved from 2.50713 to 2.48970, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.6214 - accuracy: 0.8227 - val_loss: 2.4897 - val_accuracy: 0.9354
# Epoch 235/2000
#
# Epoch 00235: val_loss improved from 2.48970 to 2.47429, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.6042 - accuracy: 0.8215 - val_loss: 2.4743 - val_accuracy: 0.9330
# Epoch 236/2000
#
# Epoch 00236: val_loss improved from 2.47429 to 2.45474, saving model to ./checkpoint
# 891/891 - 7s - loss: 2.5925 - accuracy: 0.8148 - val_loss: 2.4547 - val_accuracy: 0.9306
# Epoch 237/2000
#
# Epoch 00237: val_loss improved from 2.45474 to 2.43715, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.5709 - accuracy: 0.8193 - val_loss: 2.4371 - val_accuracy: 0.9330
# Epoch 238/2000
#
# Epoch 00238: val_loss improved from 2.43715 to 2.42077, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.5540 - accuracy: 0.8260 - val_loss: 2.4208 - val_accuracy: 0.9378
# Epoch 239/2000
#
# Epoch 00239: val_loss improved from 2.42077 to 2.40381, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.5387 - accuracy: 0.8193 - val_loss: 2.4038 - val_accuracy: 0.9258
# Epoch 240/2000
#
# Epoch 00240: val_loss improved from 2.40381 to 2.38434, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.5252 - accuracy: 0.8182 - val_loss: 2.3843 - val_accuracy: 0.9378
# Epoch 241/2000
#
# Epoch 00241: val_loss improved from 2.38434 to 2.36942, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.5106 - accuracy: 0.8238 - val_loss: 2.3694 - val_accuracy: 0.9378
# Epoch 242/2000
#
# Epoch 00242: val_loss improved from 2.36942 to 2.35542, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.4920 - accuracy: 0.8193 - val_loss: 2.3554 - val_accuracy: 0.9234
# Epoch 243/2000
#
# Epoch 00243: val_loss improved from 2.35542 to 2.34133, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.4718 - accuracy: 0.8260 - val_loss: 2.3413 - val_accuracy: 0.9354
# Epoch 244/2000
#
# Epoch 00244: val_loss improved from 2.34133 to 2.32573, saving model to ./checkpoint
# 891/891 - 8s - loss: 2.4628 - accuracy: 0.8215 - val_loss: 2.3257 - val_accuracy: 0.9330
# Epoch 245/2000
#
# Epoch 00245: val_loss improved from 2.32573 to 2.30862, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.4424 - accuracy: 0.8159 - val_loss: 2.3086 - val_accuracy: 0.9402
# Epoch 246/2000
#
# Epoch 00246: val_loss improved from 2.30862 to 2.29609, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.4290 - accuracy: 0.8316 - val_loss: 2.2961 - val_accuracy: 0.9330
# Epoch 247/2000
#
# Epoch 00247: val_loss improved from 2.29609 to 2.27658, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.4148 - accuracy: 0.8171 - val_loss: 2.2766 - val_accuracy: 0.9402
# Epoch 248/2000
#
# Epoch 00248: val_loss improved from 2.27658 to 2.26294, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.3967 - accuracy: 0.8193 - val_loss: 2.2629 - val_accuracy: 0.9282
# Epoch 249/2000
#
# Epoch 00249: val_loss improved from 2.26294 to 2.24937, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.3828 - accuracy: 0.8204 - val_loss: 2.2494 - val_accuracy: 0.9354
# Epoch 250/2000
#
# Epoch 00250: val_loss improved from 2.24937 to 2.23676, saving model to ./checkpoint
# 891/891 - 6s - loss: 2.3678 - accuracy: 0.8272 - val_loss: 2.2368 - val_accuracy: 0.9258
# Epoch 251/2000
#
# Epoch 00251: val_loss improved from 2.23676 to 2.22120, saving model to ./checkpoint
# ...
# 891/891 - 4s - loss: 0.4858 - accuracy: 0.8328 - val_loss: 0.3822 - val_accuracy: 0.9019
# Epoch 1611/2000
#
# Epoch 01611: val_loss improved from 0.38135 to 0.38109, saving model to ./checkpoint
# 891/891 - 6s - loss: 0.4940 - accuracy: 0.8339 - val_loss: 0.3811 - val_accuracy: 0.9091
# Epoch 1612/2000
#
# Epoch 01612: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.5093 - accuracy: 0.8249 - val_loss: 0.3820 - val_accuracy: 0.9091
# Epoch 1613/2000
#
# Epoch 01613: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.5023 - accuracy: 0.8215 - val_loss: 0.3833 - val_accuracy: 0.9091
# Epoch 1614/2000
#
# Epoch 01614: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.4941 - accuracy: 0.8316 - val_loss: 0.3832 - val_accuracy: 0.9091
# Epoch 1615/2000
#
# Epoch 01615: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.4936 - accuracy: 0.8328 - val_loss: 0.3828 - val_accuracy: 0.9187
# Epoch 1616/2000
#
# Epoch 01616: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.5003 - accuracy: 0.8249 - val_loss: 0.3822 - val_accuracy: 0.9091
# Epoch 1617/2000
#
# Epoch 01617: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.4954 - accuracy: 0.8406 - val_loss: 0.3825 - val_accuracy: 0.9211
# Epoch 1618/2000
#
# Epoch 01618: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.4995 - accuracy: 0.8294 - val_loss: 0.3821 - val_accuracy: 0.9115
# Epoch 1619/2000
#
# Epoch 01619: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.4993 - accuracy: 0.8339 - val_loss: 0.3821 - val_accuracy: 0.9091
# Epoch 1620/2000
#
# Epoch 01620: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.4934 - accuracy: 0.8316 - val_loss: 0.3831 - val_accuracy: 0.9091
# Epoch 1621/2000
#
# Epoch 01621: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.4962 - accuracy: 0.8350 - val_loss: 0.3821 - val_accuracy: 0.9115
# Epoch 1622/2000
#
# Epoch 01622: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.4969 - accuracy: 0.8238 - val_loss: 0.3827 - val_accuracy: 0.9187
# Epoch 1623/2000
#
# Epoch 01623: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.4964 - accuracy: 0.8339 - val_loss: 0.3815 - val_accuracy: 0.9163
# Epoch 1624/2000
#
# Epoch 01624: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.5008 - accuracy: 0.8159 - val_loss: 0.3826 - val_accuracy: 0.9115
# Epoch 1625/2000
#
# Epoch 01625: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.5037 - accuracy: 0.8283 - val_loss: 0.3829 - val_accuracy: 0.9163
# Epoch 1626/2000
#
# Epoch 01626: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.4946 - accuracy: 0.8350 - val_loss: 0.3821 - val_accuracy: 0.9091
# Epoch 1627/2000
#
# Epoch 01627: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.5016 - accuracy: 0.8193 - val_loss: 0.3812 - val_accuracy: 0.9115
# Epoch 1628/2000
#
# Epoch 01628: val_loss did not improve from 0.38109
# 891/891 - 4s - loss: 0.5021 - accuracy: 0.8204 - val_loss: 0.3819 - val_accuracy: 0.9091
# Epoch 1629/2000
#
# Epoch 01629: val_loss improved from 0.38109 to 0.38094, saving model to ./checkpoint
# 891/891 - 6s - loss: 0.4990 - accuracy: 0.8328 - val_loss: 0.3809 - val_accuracy: 0.9091
# Epoch 1630/2000
#
# Epoch 01630: val_loss did not improve from 0.38094
# 891/891 - 4s - loss: 0.4939 - accuracy: 0.8294 - val_loss: 0.3816 - val_accuracy: 0.9115
# Epoch 1631/2000
#
# Epoch 01631: val_loss did not improve from 0.38094
# 891/891 - 4s - loss: 0.4992 - accuracy: 0.8238 - val_loss: 0.3816 - val_accuracy: 0.9115
# Epoch 1632/2000
#
# Epoch 01632: val_loss did not improve from 0.38094
# 891/891 - 4s - loss: 0.5006 - accuracy: 0.8328 - val_loss: 0.3831 - val_accuracy: 0.9091
# Epoch 1633/2000
#
# Epoch 01633: val_loss did not improve from 0.38094
# 891/891 - 4s - loss: 0.4955 - accuracy: 0.8328 - val_loss: 0.3837 - val_accuracy: 0.9091
# Epoch 1634/2000
#
# Epoch 01634: val_loss did not improve from 0.38094
# 891/891 - 4s - loss: 0.4977 - accuracy: 0.8350 - val_loss: 0.3822 - val_accuracy: 0.9091
# Epoch 1635/2000
#
# Epoch 01635: val_loss did not improve from 0.38094
# 891/891 - 4s - loss: 0.4965 - accuracy: 0.8350 - val_loss: 0.3821 - val_accuracy: 0.9115
# Epoch 1636/2000
#
# Epoch 01636: val_loss did not improve from 0.38094
# 891/891 - 4s - loss: 0.4944 - accuracy: 0.8260 - val_loss: 0.3816 - val_accuracy: 0.9091
# Epoch 1637/2000
#
# Epoch 01637: val_loss did not improve from 0.38094
# 891/891 - 4s - loss: 0.4941 - accuracy: 0.8283 - val_loss: 0.3819 - val_accuracy: 0.9115
# Epoch 1638/2000
#
# Epoch 01638: val_loss did not improve from 0.38094
# 891/891 - 4s - loss: 0.4919 - accuracy: 0.8384 - val_loss: 0.3812 - val_accuracy: 0.9115
# Epoch 1639/2000
#
# Epoch 01639: val_loss improved from 0.38094 to 0.38035, saving model to ./checkpoint
# 891/891 - 6s - loss: 0.4953 - accuracy: 0.8260 - val_loss: 0.3804 - val_accuracy: 0.9115
# Epoch 1640/2000
#
# Epoch 01640: val_loss improved from 0.38035 to 0.38031, saving model to ./checkpoint
# 891/891 - 7s - loss: 0.5004 - accuracy: 0.8238 - val_loss: 0.3803 - val_accuracy: 0.9091
# Epoch 1641/2000
#
# Epoch 01641: val_loss improved from 0.38031 to 0.37971, saving model to ./checkpoint
# 891/891 - 6s - loss: 0.4978 - accuracy: 0.8305 - val_loss: 0.3797 - val_accuracy: 0.9091
# Epoch 1642/2000
#
# Epoch 01642: val_loss did not improve from 0.37971
# 891/891 - 4s - loss: 0.5001 - accuracy: 0.8227 - val_loss: 0.3814 - val_accuracy: 0.9139
# Epoch 1643/2000
#
# Epoch 01643: val_loss did not improve from 0.37971
# 891/891 - 4s - loss: 0.4890 - accuracy: 0.8294 - val_loss: 0.3800 - val_accuracy: 0.9091
# Epoch 1644/2000
#
# Epoch 01644: val_loss did not improve from 0.37971
# 891/891 - 4s - loss: 0.4954 - accuracy: 0.8193 - val_loss: 0.3798 - val_accuracy: 0.9115
# Epoch 1645/2000
#
# Epoch 01645: val_loss did not improve from 0.37971
# 891/891 - 4s - loss: 0.4892 - accuracy: 0.8395 - val_loss: 0.3802 - val_accuracy: 0.9115
# Epoch 1646/2000
#
# Epoch 01646: val_loss did not improve from 0.37971
# 891/891 - 4s - loss: 0.4908 - accuracy: 0.8305 - val_loss: 0.3800 - val_accuracy: 0.9163
# Epoch 1647/2000
#
# Epoch 01647: val_loss improved from 0.37971 to 0.37848, saving model to ./checkpoint
# 891/891 - 6s - loss: 0.4983 - accuracy: 0.8294 - val_loss: 0.3785 - val_accuracy: 0.9115
# Epoch 1648/2000
#
# Epoch 01648: val_loss did not improve from 0.37848
# 891/891 - 4s - loss: 0.4901 - accuracy: 0.8384 - val_loss: 0.3786 - val_accuracy: 0.9115
# Epoch 1649/2000
#
# Epoch 01649: val_loss did not improve from 0.37848
# 891/891 - 4s - loss: 0.4947 - accuracy: 0.8305 - val_loss: 0.3787 - val_accuracy: 0.9234
# Epoch 1650/2000
#
# Epoch 01650: val_loss improved from 0.37848 to 0.37744, saving model to ./checkpoint
# 891/891 - 6s - loss: 0.4917 - accuracy: 0.8215 - val_loss: 0.3774 - val_accuracy: 0.9091
# Epoch 1651/2000
#
# Epoch 01651: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4961 - accuracy: 0.8339 - val_loss: 0.3800 - val_accuracy: 0.9139
# Epoch 1652/2000
#
# Epoch 01652: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4902 - accuracy: 0.8373 - val_loss: 0.3796 - val_accuracy: 0.9091
# Epoch 1653/2000
#
# Epoch 01653: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4984 - accuracy: 0.8305 - val_loss: 0.3802 - val_accuracy: 0.9139
# Epoch 1654/2000
#
# Epoch 01654: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4947 - accuracy: 0.8182 - val_loss: 0.3806 - val_accuracy: 0.9211
# Epoch 1655/2000
#
# Epoch 01655: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.5010 - accuracy: 0.8294 - val_loss: 0.3794 - val_accuracy: 0.9115
# Epoch 1656/2000
#
# Epoch 01656: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4988 - accuracy: 0.8350 - val_loss: 0.3808 - val_accuracy: 0.9091
# Epoch 1657/2000
#
# Epoch 01657: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4906 - accuracy: 0.8328 - val_loss: 0.3808 - val_accuracy: 0.9115
# Epoch 1658/2000
#
# Epoch 01658: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4957 - accuracy: 0.8249 - val_loss: 0.3791 - val_accuracy: 0.9091
# Epoch 1659/2000
#
# Epoch 01659: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4951 - accuracy: 0.8328 - val_loss: 0.3800 - val_accuracy: 0.9091
# Epoch 1660/2000
#
# Epoch 01660: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4933 - accuracy: 0.8249 - val_loss: 0.3803 - val_accuracy: 0.9115
# Epoch 1661/2000
#
# Epoch 01661: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4979 - accuracy: 0.8260 - val_loss: 0.3802 - val_accuracy: 0.9115
# Epoch 1662/2000
#
# Epoch 01662: val_loss did not improve from 0.37744
# 891/891 - 5s - loss: 0.4969 - accuracy: 0.8238 - val_loss: 0.3805 - val_accuracy: 0.9115
# Epoch 1663/2000
#
# Epoch 01663: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4910 - accuracy: 0.8339 - val_loss: 0.3791 - val_accuracy: 0.9115
# Epoch 1664/2000
#
# Epoch 01664: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4987 - accuracy: 0.8305 - val_loss: 0.3798 - val_accuracy: 0.9115
# Epoch 1665/2000
#
# Epoch 01665: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4966 - accuracy: 0.8316 - val_loss: 0.3794 - val_accuracy: 0.9091
# Epoch 1666/2000
#
# Epoch 01666: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4969 - accuracy: 0.8238 - val_loss: 0.3806 - val_accuracy: 0.9163
# Epoch 1667/2000
#
# Epoch 01667: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4884 - accuracy: 0.8171 - val_loss: 0.3789 - val_accuracy: 0.9115
# Epoch 1668/2000
#
# Epoch 01668: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4950 - accuracy: 0.8361 - val_loss: 0.3796 - val_accuracy: 0.9091
# Epoch 1669/2000
#
# Epoch 01669: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4922 - accuracy: 0.8260 - val_loss: 0.3797 - val_accuracy: 0.9115
# Epoch 1670/2000
#
# Epoch 01670: val_loss did not improve from 0.37744
# 891/891 - 5s - loss: 0.4949 - accuracy: 0.8305 - val_loss: 0.3796 - val_accuracy: 0.9091
# Epoch 1671/2000
#
# Epoch 01671: val_loss did not improve from 0.37744
# 891/891 - 5s - loss: 0.4927 - accuracy: 0.8294 - val_loss: 0.3805 - val_accuracy: 0.9115
# Epoch 1672/2000
#
# Epoch 01672: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4913 - accuracy: 0.8305 - val_loss: 0.3810 - val_accuracy: 0.9091
# Epoch 1673/2000
#
# Epoch 01673: val_loss did not improve from 0.37744
# 891/891 - 5s - loss: 0.4964 - accuracy: 0.8249 - val_loss: 0.3802 - val_accuracy: 0.9115
# Epoch 1674/2000
#
# Epoch 01674: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.5028 - accuracy: 0.8227 - val_loss: 0.3818 - val_accuracy: 0.9187
# Epoch 1675/2000
#
# Epoch 01675: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4948 - accuracy: 0.8294 - val_loss: 0.3798 - val_accuracy: 0.9115
# Epoch 1676/2000
#
# Epoch 01676: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4947 - accuracy: 0.8249 - val_loss: 0.3812 - val_accuracy: 0.9115
# Epoch 1677/2000
#
# Epoch 01677: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4877 - accuracy: 0.8339 - val_loss: 0.3798 - val_accuracy: 0.9091
# Epoch 1678/2000
#
# Epoch 01678: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4902 - accuracy: 0.8272 - val_loss: 0.3812 - val_accuracy: 0.9187
# Epoch 1679/2000
#
# Epoch 01679: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.5033 - accuracy: 0.8249 - val_loss: 0.3797 - val_accuracy: 0.9091
# Epoch 1680/2000
#
# Epoch 01680: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4909 - accuracy: 0.8260 - val_loss: 0.3796 - val_accuracy: 0.9091
# Epoch 1681/2000
#
# Epoch 01681: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4940 - accuracy: 0.8227 - val_loss: 0.3790 - val_accuracy: 0.9115
# Epoch 1682/2000
#
# Epoch 01682: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4952 - accuracy: 0.8215 - val_loss: 0.3796 - val_accuracy: 0.9115
# Epoch 1683/2000
#
# Epoch 01683: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4915 - accuracy: 0.8227 - val_loss: 0.3784 - val_accuracy: 0.9115
# Epoch 1684/2000
#
# Epoch 01684: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4921 - accuracy: 0.8384 - val_loss: 0.3790 - val_accuracy: 0.9139
# Epoch 1685/2000
#
# Epoch 01685: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4893 - accuracy: 0.8249 - val_loss: 0.3793 - val_accuracy: 0.9211
# Epoch 1686/2000
#
# Epoch 01686: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4900 - accuracy: 0.8316 - val_loss: 0.3785 - val_accuracy: 0.9091
# Epoch 1687/2000
#
# Epoch 01687: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4968 - accuracy: 0.8249 - val_loss: 0.3791 - val_accuracy: 0.9091
# Epoch 1688/2000
#
# Epoch 01688: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4914 - accuracy: 0.8339 - val_loss: 0.3784 - val_accuracy: 0.9187
# Epoch 1689/2000
#
# Epoch 01689: val_loss did not improve from 0.37744
# 891/891 - 4s - loss: 0.4916 - accuracy: 0.8350 - val_loss: 0.3779 - val_accuracy: 0.9115
# Epoch 1690/2000
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 891/891 - 4s - loss: 0.4916 - accuracy: 0.8361
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-5f3b0297d7fb> in <module>
#       4           verbose = 2,
#       5           validation_data = (testX,testY),
# ----> 6           callbacks=[cp_callback],
#       7          )
#       8
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     726         max_queue_size=max_queue_size,
#     727         workers=workers,
# --> 728         use_multiprocessing=use_multiprocessing)
#     729
#     730   def evaluate(self,
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     335                 eval_data_iter._initializer  # pylint: disable=pointless-statement
#     336               else:
# --> 337                 eval_data_iter = iter(validation_dataset)
#     338
#     339               validation_callbacks = cbks.configure_callbacks(
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\data\ops\dataset_ops.py in __iter__(self)
#     330     if (context.executing_eagerly()
#     331         or ops.get_default_graph()._building_function):  # pylint: disable=protected-access
# --> 332       return iterator_ops.IteratorV2(self)
#     333     else:
#     334       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\data\ops\iterator_ops.py in __init__(self, dataset, components, element_spec)
#     591           context.context().device_spec.device_type != "CPU"):
#     592         with ops.device("/cpu:0"):
# --> 593           self._create_iterator(dataset)
#     594       else:
#     595         self._create_iterator(dataset)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\data\ops\iterator_ops.py in _create_iterator(self, dataset)
#     609               output_types=self._flat_output_types,
#     610               output_shapes=self._flat_output_shapes))
# --> 611       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     612       # Delete the resource when this object is deleted
#     613       self._resource_deleter = IteratorResourceDeleter(
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    2913         _ctx._context_handle, _ctx._thread_local_data.device_name,
#    2914         "MakeIterator", name, _ctx._post_execution_callbacks, dataset,
# -> 2915         iterator)
#    2916       return _result
#    2917     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
# evaluate
test_loss, test_acc = model.evaluate(testX,testY,verbose = 0)

print('test accuracy: {}, test loss: {}'.format(test_acc,test_loss))

# %%
# predictions
predictions = model.predict_classes(testX).reshape(len(predictions))
# write csv file
submission =pd.DataFrame({'PassengerId':testData['PassengerId'],'Survived':predictions})
submission.to_csv('Titanic Predictions.csv',index = False)
